# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive

gauth = GoogleAuth()
gauth.LocalWebserverAuth()
drive = GoogleDrive(gauth)

# %%
file_list = []
while(len(file_list)==0):
    file_list = drive.ListFile({'q': "trashed=false and title='startup.py'"}).GetList()

# %%
file = drive.CreateFile({'id': '19Fis_Wnj6RDdjDQeFYlpNVG-CI0HPPlt'})
file.Delete()

# %%
file1
