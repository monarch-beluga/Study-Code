# %%
import geemap
import ee

# %%
Map = geemap.Map(center=(36, 117))
Map
# Out:
# Map(center=[36, 117], controls=(WidgetControl(options=['position'], widget=HBox(children=(ToggleButton(value=F…

# %%
roi = Map.draw_last_feature.geometry()

# %%
images = (ee.ImageCollection("LANDSAT/LT05/C01/T1").filterBounds(roi)
            .sort("CLOUD_COVER"))

# %%
Map.addLayer(images.first(), {'bands': ['B4', 'B3', 'B2']}, "imags")

# %%
images.first().getInfo()
# Out:
# {'type': 'Image',
#  'bands': [{'id': 'B1',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [7801, 7041],
#    'crs': 'EPSG:32650',
#    'crs_transform': [30, 0, 342885, 0, -30, 3297015]},
#   {'id': 'B2',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [7801, 7041],
#    'crs': 'EPSG:32650',
#    'crs_transform': [30, 0, 342885, 0, -30, 3297015]},
#   {'id': 'B3',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [7801, 7041],
#    'crs': 'EPSG:32650',
#    'crs_transform': [30, 0, 342885, 0, -30, 3297015]},
#   {'id': 'B4',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [7801, 7041],
#    'crs': 'EPSG:32650',
#    'crs_transform': [30, 0, 342885, 0, -30, 3297015]},
#   {'id': 'B5',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [7801, 7041],
#    'crs': 'EPSG:32650',
#    'crs_transform': [30, 0, 342885, 0, -30, 3297015]},
#   {'id': 'B6',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [7801, 7041],
#    'crs': 'EPSG:32650',
#    'crs_transform': [30, 0, 342885, 0, -30, 3297015]},
#   {'id': 'B7',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [7801, 7041],
#    'crs': 'EPSG:32650',
#    'crs_transform': [30, 0, 342885, 0, -30, 3297015]},
#   {'id': 'BQA',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [7801, 7041],
#    'crs': 'EPSG:32650',
#    'crs_transform': [30, 0, 342885, 0, -30, 3297015]}],
#  'id': 'LANDSAT/LT05/C01/T1/LT05_121040_19871217',
#  'version': 1504176204733733,
#  'properties': {'RADIANCE_MULT_BAND_5': 0.12035000324249268,
#   'RADIANCE_MULT_BAND_6': 0.05537499859929085,
#   'IMAGE_QUALITY': 7,
#   'RADIANCE_MULT_BAND_3': 1.0440000295639038,
#   'RADIANCE_MULT_BAND_4': 0.8760200142860413,
#   'RADIANCE_MULT_BAND_1': 0.6713399887084961,
#   'RADIANCE_MULT_BAND_2': 1.3221999406814575,
#   'K2_CONSTANT_BAND_6': 1260.56005859375,
#   'CORRECTION_GAIN_BAND_2': 'CPF',
#   'CORRECTION_GAIN_BAND_1': 'CPF',
#   'system:footprint': {'type': 'LinearRing',
#    'coordinates': [[115.58323203454046, 28.952023698886094],
#     [115.41845522954706, 28.28295298266026],
#     [115.40174652229828, 28.2137090272873],
#     [115.3989276561678, 28.19740125577922],
#     [115.39913575885983, 28.183435275636437],
#     [117.34485028534985, 27.899294943598374],
#     [117.35532659270135, 27.906304028818834],
#     [117.36116901814957, 27.91358596684772],
#     [117.38963556872443, 28.016561141591012],
#     [117.43549180095557, 28.188118742813128],
#     [117.49957987179822, 28.429183936867755],
#     [117.66997069535492, 29.066137133453946],
#     [117.73486537490848, 29.30704491172082],
#     [117.78271558507561, 29.485750941310403],
#     [117.78430243150767, 29.50436890276856],
#     [117.77314197174289, 29.508411308065572],
#     [115.79447615114007, 29.797575878426635],
#     [115.7499569656661, 29.62089909387628],
#     [115.58323203454046, 28.952023698886094]]},
#   'REFLECTIVE_SAMPLES': 7801,
#   'CORRECTION_GAIN_BAND_7': 'CPF',
#   'CORRECTION_GAIN_BAND_6': 'INTERNAL_CALIBRATION',
#   'CORRECTION_GAIN_BAND_5': 'CPF',
#   'SUN_AZIMUTH': 148.6688690185547,
#   'CORRECTION_GAIN_BAND_4': 'CPF',
#   'CORRECTION_GAIN_BAND_3': 'CPF',
#   'CPF_NAME': 'LT05CPF_19871001_19871231_01.03',
#   'DATE_ACQUIRED': '1987-12-17',
#   'ELLIPSOID': 'WGS84',
#   'google:registration_offset_x': -29.34401512145996,
#   'google:registration_offset_y': -3.1112983226776123,
#   'SENSOR_MODE': 'SAM',
#   'STATION_ID': 'BJC',
#   'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION',
#   'ORIENTATION': 'NORTH_UP',
#   'WRS_ROW': 40,
#   'RADIANCE_MULT_BAND_7': 0.06555099785327911,
#   'CLOUD_COVER': 0,
#   'GEOMETRIC_RMSE_VERIFY': 0.2070000022649765,
#   'COLLECTION_CATEGORY': 'T1',
#   'GRID_CELL_SIZE_REFLECTIVE': 30,
#   'DATA_CATEGORY': 'NOMINAL',
#   'K1_CONSTANT_BAND_6': 607.760009765625,
#   'CLOUD_COVER_LAND': 0,
#   'GEOMETRIC_RMSE_MODEL': 5.7820000648498535,
#   'COLLECTION_NUMBER': 1,
#   'LANDSAT_SCENE_ID': 'LT51210401987351BJC00',
#   'WRS_PATH': 121,
#   'google:registration_count': 10889,
#   'MAP_PROJECTION_L0RA': 'NA',
#   'GEOMETRIC_RMSE_MODEL_Y': 3.933000087738037,
#   'REFLECTIVE_LINES': 7041,
#   'GEOMETRIC_RMSE_MODEL_X': 4.23799991607666,
#   'system:asset_size': 180037814,
#   'system:index': 'LT05_121040_19871217',
#   'GEOMETRIC_RMSE_VERIFY_QUAD_LL': 0.1940000057220459,
#   'GEOMETRIC_RMSE_VERIFY_QUAD_LR': 0.2160000056028366,
#   'REFLECTANCE_ADD_BAND_1': -0.00343000004068017,
#   'REFLECTANCE_ADD_BAND_2': -0.007199000101536512,
#   'DATUM': 'WGS84',
#   'REFLECTANCE_ADD_BAND_3': -0.004521000199019909,
#   'REFLECTANCE_ADD_BAND_4': -0.007027000188827515,
#   'REFLECTANCE_ADD_BAND_5': -0.00711800018325448,
#   'REFLECTANCE_ADD_BAND_7': -0.007973999716341496,
#   'GROUND_CONTROL_POINTS_VERSION': 4,
#   'DATA_TYPE': 'L1TP',
#   'GEOMETRIC_RMSE_VERIFY_QUAD_UL': 0.21799999475479126,
#   'CORRECTION_BIAS_BAND_2': 'CPF',
#   'CORRECTION_BIAS_BAND_1': 'CPF',
#   'GEOMETRIC_RMSE_VERIFY_QUAD_UR': 0.2029999941587448,
#   'CORRECTION_BIAS_BAND_4': 'CPF',
#   'CORRECTION_BIAS_BAND_3': 'CPF',
#   'DATA_TYPE_L0RP': 'TMR_L0RP',
#   'UTM_ZONE': 50,
#   'LANDSAT_PRODUCT_ID': 'LT05_L1TP_121040_19871217_20170418_01_T1',
#   'google:registration_ratio': 0.9741456508636475,
#   'RADIANCE_ADD_BAND_4': -2.3860199451446533,
#   'REFLECTANCE_MULT_BAND_7': 0.0024250000715255737,
#   'system:time_start': 566705575245,
#   'RADIANCE_ADD_BAND_5': -0.49035000801086426,
#   'RADIANCE_ADD_BAND_6': 1.1824300289154053,
#   'PROCESSING_SOFTWARE_VERSION': 'LPGS_12.8.4',
#   'RADIANCE_ADD_BAND_7': -0.2155500054359436,
#   'EPHEMERIS_TYPE': 'DEFINITIVE',
#   'RADIANCE_ADD_BAND_1': -2.1913399696350098,
#   'RADIANCE_ADD_BAND_2': -4.162199974060059,
#   'RADIANCE_ADD_BAND_3': -2.213979959487915,
#   'REFLECTANCE_MULT_BAND_1': 0.0010506999678909779,
#   'CORRECTION_BIAS_BAND_6': 'CPF',
#   'REFLECTANCE_MULT_BAND_3': 0.002131700050085783,
#   'CORRECTION_BIAS_BAND_5': 'CPF',
#   'REFLECTANCE_MULT_BAND_2': 0.0022869000677019358,
#   'REFLECTANCE_MULT_BAND_5': 0.0017470000311732292,
#   'CORRECTION_BIAS_BAND_7': 'CPF',
#   'REFLECTANCE_MULT_BAND_4': 0.0025800999719649553,
#   'THERMAL_LINES': 7041,
#   'GRID_CELL_SIZE_THERMAL': 30,
#   'REQUEST_ID': '0501704189007_01949',
#   'EARTH_SUN_DISTANCE': 0.9840903878211975,
#   'FILE_DATE': 1492540075000,
#   'SCENE_CENTER_TIME': '02:12:55.2450500Z',
#   'SUN_ELEVATION': 30.76365852355957,
#   'SATURATION_BAND_1': 'N',
#   'SATURATION_BAND_2': 'Y',
#   'SATURATION_BAND_3': 'Y',
#   'SATURATION_BAND_4': 'Y',
#   'SATURATION_BAND_5': 'Y',
#   'MAP_PROJECTION': 'UTM',
#   'SATURATION_BAND_6': 'N',
#   'SENSOR_ID': 'TM',
#   'SATURATION_BAND_7': 'Y',
#   'GROUND_CONTROL_POINTS_MODEL': 146,
#   'SPACECRAFT_ID': 'LANDSAT_5',
#   'ELEVATION_SOURCE': 'GLS2000',
#   'THERMAL_SAMPLES': 7801,
#   'GROUND_CONTROL_POINTS_VERIFY': 2529}}

# %%
image = ee.Image('LANDSAT/LT05/C01/T1/LT05_121040_19871217')
# Map.addLayer(image, {'bands': ['B4', 'B3', 'B2']}, "imag")

# %%
roi = Map.draw_features[1].geometry()

# %%
geemap.ee_export_image_to_drive(image, description='LE7_121040_20000127',
                                folder='Image', scale=30)

# %%
file = r"E:/LT05_121040_19871217.tif"
geemap.ee_export_image(image, region=roi, filename=file, scale=15, file_per_band=False)
# Out:
# Generating URL ...
# An error occurred while downloading.
# Total request size (525567096 bytes) must be less than or equal to 33554432 bytes.

# %%
Map.draw_features
